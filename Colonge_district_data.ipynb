# %% [markdown]
# <a href="https://colab.research.google.com/github/rucha0209-pro/Applied-Data-Science-Capstone-/blob/main/Colonge_district_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Data about Cologne**

# %%
import numpy as np 
import pandas as pd 

# !conda install -c conda-forge lxml --yes
print("Libraries installed.")
# Out:
# ERROR: The install method you used for conda--probably either `pip install conda`
# or `easy_install conda`--is not compatible with using conda as an application.
# If your intention is to install conda as a standalone application, currently
# supported install methods include the Anaconda installer and the miniconda
# installer.  You can download the miniconda installer from
# https://conda.io/miniconda.html.
#
# Libraries installed.

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/Districts_of_Cologne#Districts')[1]

# %%
df
# Out:
#                                                   Map  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  Notes: 1: population as of 31. December 2008 2...
#
#                                                  Coat  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  Notes: 1: population as of 31. December 2008 2...
#
#                                         City district  \
# 0                          District 1 Köln-Innenstadt
# 1                        District 2 Köln-Rodenkirchen
# 2                          District 3 Köln-Lindenthal
# 3                           District 4 Köln-Ehrenfeld
# 4                              District 5 Köln-Nippes
# 5                          District 6 Köln-Chorweiler
# 6                                District 7 Köln-Porz
# 7                                District 8 Köln-Kalk
# 8                             District 9 Köln-Mülheim
# 9                                             Cologne
# 10  Notes: 1: population as of 31. December 2008 2...
#
#                                            City parts  \
# 0   Altstadt-Nord, Altstadt-Süd, Deutz, Neustadt-N...
# 1   Bayenthal, Godorf, Hahnwald, Immendorf, Marien...
# 2   Braunsfeld, Junkersdorf, Klettenberg, Lindenth...
# 3   Bickendorf, Bocklemünd/Mengenich, Ehrenfeld, N...
# 4   Bilderstöckchen, Longerich, Mauenheim, Niehl, ...
# 5   Blumenberg, Chorweiler, Esch/Auweiler, Fühling...
# 6   Eil, Elsdorf, Ensen, Finkenberg, Gremberghoven...
# 7   Brück, Höhenberg, Humboldt/Gremberg, Kalk, Mer...
# 8   Buchforst, Buchheim, Dellbrück, Dünnwald, Flit...
# 9                                                 NaN
# 10  Notes: 1: population as of 31. December 2008 2...
#
#                                                  Area  \
# 0                                            16.4 km²
# 1                                            54.6 km²
# 2                                            41.6 km²
# 3                                            23.8 km²
# 4                                            31.8 km²
# 5                                            67.2 km²
# 6                                            78.8 km²
# 7                                            38.2 km²
# 8                                            52.2 km²
# 9                                          405.15 km2
# 10  Notes: 1: population as of 31. December 2008 2...
#
#                                           Population1  \
# 0                                             127.033
# 1                                             100.936
# 2                                             137.552
# 3                                             103.621
# 4                                             110.092
# 5                                              80.870
# 6                                             106.520
# 7                                             108.330
# 8                                             144.374
# 9                                          1.019.3282
# 10  Notes: 1: population as of 31. December 2008 2...
#
#                                          Pop. density  \
# 0                                           7.746/km²
# 1                                           1.850/km²
# 2                                           3.308/km²
# 3                                           4.348/km²
# 4                                           3.462/km²
# 5                                           1.204/km²
# 6                                           1.352/km²
# 7                                           2.841/km²
# 8                                           2.764/km²
# 9                                           2.516/km2
# 10  Notes: 1: population as of 31. December 2008 2...
#
#                                     District Councils  \
# 0   Bezirksksamt Innenstadt Brückenstraße 19, D-50...
# 1   Bezirksamt Rodenkirchen Hauptstraße 85, D-5099...
# 2   Bezirksamt Lindenthal Aachener Straße 220, 509...
# 3   Bezirksamt Ehrenfeld Venloer Straße 419 – 421,...
# 4    Bezirksamt NippesNeusser Straße 450,D-50733 Köln
# 5   Bezirksamt Chorweiler Pariser Platz 1, D-50765...
# 6   Bezirksamt PorzFriedrich-Ebert-Ufer 64–70, D-5...
# 7   Bezirksamt KalkKalker Hauptstraße 247–273,D-51...
# 8     Bezirksamt Mülheim Wiener Platz 2a,D-51065 Köln
# 9                                           2.516/km2
# 10  Notes: 1: population as of 31. December 2008 2...
#
#                                             Town Hall
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                           2.516/km2
# 10  Notes: 1: population as of 31. December 2008 2...

# %%
df.drop("Map", axis=1, inplace=True)

# %%
df.drop("Coat", axis=1, inplace=True)

# %%
df.drop("Town Hall", axis=1, inplace=True)

# %%
df.head()
# Out:
#                   City district  \
# 0    District 1 Köln-Innenstadt
# 1  District 2 Köln-Rodenkirchen
# 2    District 3 Köln-Lindenthal
# 3     District 4 Köln-Ehrenfeld
# 4        District 5 Köln-Nippes
#
#                                           City parts      Area Population1  \
# 0  Altstadt-Nord, Altstadt-Süd, Deutz, Neustadt-N...  16.4 km²     127.033
# 1  Bayenthal, Godorf, Hahnwald, Immendorf, Marien...  54.6 km²     100.936
# 2  Braunsfeld, Junkersdorf, Klettenberg, Lindenth...  41.6 km²     137.552
# 3  Bickendorf, Bocklemünd/Mengenich, Ehrenfeld, N...  23.8 km²     103.621
# 4  Bilderstöckchen, Longerich, Mauenheim, Niehl, ...  31.8 km²     110.092
#
#   Pop. density                                  District Councils
# 0    7.746/km²  Bezirksksamt Innenstadt Brückenstraße 19, D-50...
# 1    1.850/km²  Bezirksamt Rodenkirchen Hauptstraße 85, D-5099...
# 2    3.308/km²  Bezirksamt Lindenthal Aachener Straße 220, 509...
# 3    4.348/km²  Bezirksamt Ehrenfeld Venloer Straße 419 – 421,...
# 4    3.462/km²   Bezirksamt NippesNeusser Straße 450,D-50733 Köln

# %%
df["City district"]=df["City district"].str[11:]

# %%
df
# Out:
#                                         City district  \
# 0                                     Köln-Innenstadt
# 1                                   Köln-Rodenkirchen
# 2                                     Köln-Lindenthal
# 3                                      Köln-Ehrenfeld
# 4                                         Köln-Nippes
# 5                                     Köln-Chorweiler
# 6                                           Köln-Porz
# 7                                           Köln-Kalk
# 8                                        Köln-Mülheim
# 9
# 10  opulation as of 31. December 2008 2: Statistic...
#
#                                            City parts  \
# 0   Altstadt-Nord, Altstadt-Süd, Deutz, Neustadt-N...
# 1   Bayenthal, Godorf, Hahnwald, Immendorf, Marien...
# 2   Braunsfeld, Junkersdorf, Klettenberg, Lindenth...
# 3   Bickendorf, Bocklemünd/Mengenich, Ehrenfeld, N...
# 4   Bilderstöckchen, Longerich, Mauenheim, Niehl, ...
# 5   Blumenberg, Chorweiler, Esch/Auweiler, Fühling...
# 6   Eil, Elsdorf, Ensen, Finkenberg, Gremberghoven...
# 7   Brück, Höhenberg, Humboldt/Gremberg, Kalk, Mer...
# 8   Buchforst, Buchheim, Dellbrück, Dünnwald, Flit...
# 9                                                 NaN
# 10  Notes: 1: population as of 31. December 2008 2...
#
#                                                  Area  \
# 0                                            16.4 km²
# 1                                            54.6 km²
# 2                                            41.6 km²
# 3                                            23.8 km²
# 4                                            31.8 km²
# 5                                            67.2 km²
# 6                                            78.8 km²
# 7                                            38.2 km²
# 8                                            52.2 km²
# 9                                          405.15 km2
# 10  Notes: 1: population as of 31. December 2008 2...
#
#                                           Population1  \
# 0                                             127.033
# 1                                             100.936
# 2                                             137.552
# 3                                             103.621
# 4                                             110.092
# 5                                              80.870
# 6                                             106.520
# 7                                             108.330
# 8                                             144.374
# 9                                          1.019.3282
# 10  Notes: 1: population as of 31. December 2008 2...
#
#                                          Pop. density  \
# 0                                           7.746/km²
# 1                                           1.850/km²
# 2                                           3.308/km²
# 3                                           4.348/km²
# 4                                           3.462/km²
# 5                                           1.204/km²
# 6                                           1.352/km²
# 7                                           2.841/km²
# 8                                           2.764/km²
# 9                                           2.516/km2
# 10  Notes: 1: population as of 31. December 2008 2...
#
#                                     District Councils
# 0   Bezirksksamt Innenstadt Brückenstraße 19, D-50...
# 1   Bezirksamt Rodenkirchen Hauptstraße 85, D-5099...
# 2   Bezirksamt Lindenthal Aachener Straße 220, 509...
# 3   Bezirksamt Ehrenfeld Venloer Straße 419 – 421,...
# 4    Bezirksamt NippesNeusser Straße 450,D-50733 Köln
# 5   Bezirksamt Chorweiler Pariser Platz 1, D-50765...
# 6   Bezirksamt PorzFriedrich-Ebert-Ufer 64–70, D-5...
# 7   Bezirksamt KalkKalker Hauptstraße 247–273,D-51...
# 8     Bezirksamt Mülheim Wiener Platz 2a,D-51065 Köln
# 9                                           2.516/km2
# 10  Notes: 1: population as of 31. December 2008 2...

# %%
df.drop([10], inplace=True)

# %%
df.drop([9], inplace=True)

# %%
df.shape
# Out:
# (9, 6)

# %% [markdown]
# ## **Geospatial data**

# %%
# !conda install -c conda-forge geopy --yes
# Out:
# /bin/bash: conda: command not found

# %%
pip install conda
# Out:
# Requirement already satisfied: conda in /usr/local/lib/python3.7/dist-packages (4.3.16)
# Requirement already satisfied: requests>=2.12.4 in /usr/local/lib/python3.7/dist-packages (from conda) (2.23.0)
# Requirement already satisfied: pycosat>=0.6.1 in /usr/local/lib/python3.7/dist-packages (from conda) (0.6.3)
# Requirement already satisfied: ruamel.yaml>=0.11.14 in /usr/local/lib/python3.7/dist-packages (from conda) (0.17.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.12.4->conda) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.12.4->conda) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.12.4->conda) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.12.4->conda) (2.10)
# Requirement already satisfied: ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.10" in /usr/local/lib/python3.7/dist-packages (from ruamel.yaml>=0.11.14->conda) (0.2.2)

# %%
pip install geopy
# Out:
# Requirement already satisfied: geopy in /usr/local/lib/python3.7/dist-packages (1.17.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /usr/local/lib/python3.7/dist-packages (from geopy) (1.50)

# %%
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
geolocator = Nominatim(user_agent="Cologne_food")

df['Major_Dist_Coord']= df['City district'].apply(geolocator.geocode).apply(lambda x: (x.latitude, x.longitude))
df[['Latitude', 'Longitude']] = df['Major_Dist_Coord'].apply(pd.Series)

df.drop(['Major_Dist_Coord'], axis=1, inplace=True)
df
# Out:
#        City district                                         City parts  \
# 0    Köln-Innenstadt  Altstadt-Nord, Altstadt-Süd, Deutz, Neustadt-N...
# 1  Köln-Rodenkirchen  Bayenthal, Godorf, Hahnwald, Immendorf, Marien...
# 2    Köln-Lindenthal  Braunsfeld, Junkersdorf, Klettenberg, Lindenth...
# 3     Köln-Ehrenfeld  Bickendorf, Bocklemünd/Mengenich, Ehrenfeld, N...
# 4        Köln-Nippes  Bilderstöckchen, Longerich, Mauenheim, Niehl, ...
# 5    Köln-Chorweiler  Blumenberg, Chorweiler, Esch/Auweiler, Fühling...
# 6          Köln-Porz  Eil, Elsdorf, Ensen, Finkenberg, Gremberghoven...
# 7          Köln-Kalk  Brück, Höhenberg, Humboldt/Gremberg, Kalk, Mer...
# 8       Köln-Mülheim  Buchforst, Buchheim, Dellbrück, Dünnwald, Flit...
#
#        Area Population1 Pop. density  \
# 0  16.4 km²     127.033    7.746/km²
# 1  54.6 km²     100.936    1.850/km²
# 2  41.6 km²     137.552    3.308/km²
# 3  23.8 km²     103.621    4.348/km²
# 4  31.8 km²     110.092    3.462/km²
# 5  67.2 km²      80.870    1.204/km²
# 6  78.8 km²     106.520    1.352/km²
# 7  38.2 km²     108.330    2.841/km²
# 8  52.2 km²     144.374    2.764/km²
#
#                                    District Councils   Latitude  Longitude
# 0  Bezirksksamt Innenstadt Brückenstraße 19, D-50...  50.937328   6.959234
# 1  Bezirksamt Rodenkirchen Hauptstraße 85, D-5099...  50.865622   6.969718
# 2  Bezirksamt Lindenthal Aachener Straße 220, 509...  50.935935   6.871246
# 3  Bezirksamt Ehrenfeld Venloer Straße 419 – 421,...  50.951502   6.916529
# 4   Bezirksamt NippesNeusser Straße 450,D-50733 Köln  50.958994   6.941777
# 5  Bezirksamt Chorweiler Pariser Platz 1, D-50765...  51.021167   6.898034
# 6  Bezirksamt PorzFriedrich-Ebert-Ufer 64–70, D-5...  50.906705   6.999129
# 7  Bezirksamt KalkKalker Hauptstraße 247–273,D-51...  50.931923   7.005806
# 8    Bezirksamt Mülheim Wiener Platz 2a,D-51065 Köln  50.958147   7.013526

# %% [markdown]
# ## **Building Clutser**

# %%
pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.7/dist-packages (0.8.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from folium) (1.15.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from folium) (2.11.3)
# Requirement already satisfied: branca>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from folium) (0.4.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from folium) (1.19.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from folium) (2.23.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->folium) (1.1.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->folium) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->folium) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->folium) (1.24.3)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# ERROR: The install method you used for conda--probably either `pip install conda`
# or `easy_install conda`--is not compatible with using conda as an application.
# If your intention is to install conda as a standalone application, currently
# supported install methods include the Anaconda installer and the miniconda
# installer.  You can download the miniconda installer from
# https://conda.io/miniconda.html.
#
# Libraries imported.

# %%
address = 'Cologne'

geolocator = Nominatim(user_agent="Cologne_food")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Cologne are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Cologne are 50.938361, 6.959974.

# %%
# create map of Cologne using latitude and longitude 
map_cologne = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to the map
for lat, lng, label in zip(df['Latitude'], df['Longitude'], df['City district']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_cologne) 
    
map_cologne
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_8e01c26801224a3e8438d079882c30dc%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_8e01c26801224a3e8438d079882c30dc%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_8e01c26801224a3e8438d079882c30dc%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_8e01c26801224a3e8438d079882c30dc%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B50.938361%2C%206.959974%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_58e85500b3514ac18198c580f0a80b5b%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%20%2 ...

# %% [markdown]
# ### Using Foursquare

# %%
#connect to Foursquare as a developer

CLIENT_ID = 'IPFKGSTEYOILEGG2MJRFNKDX2YV5WEH44MR2KZDKZOWFBXWM' # your Foursquare ID
CLIENT_SECRET = '21MX2NLSSB4PWVFR3Y04NYJJOQCNDEWTM0TMVVLVKXK2B3CD' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: IPFKGSTEYOILEGG2MJRFNKDX2YV5WEH44MR2KZDKZOWFBXWM
# CLIENT_SECRET:21MX2NLSSB4PWVFR3Y04NYJJOQCNDEWTM0TMVVLVKXK2B3CD

# %%
df.loc[0, 'City district']
# Out:
# 'Köln-Innenstadt'

# %%
neighborhood_latitude = df.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = df.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = df.loc[0, 'City district'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Köln-Innenstadt are 50.93732845, 6.959234323073302.

# %%
LIMIT = 15

radius = 600

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=IPFKGSTEYOILEGG2MJRFNKDX2YV5WEH44MR2KZDKZOWFBXWM&client_secret=21MX2NLSSB4PWVFR3Y04NYJJOQCNDEWTM0TMVVLVKXK2B3CD&v=20180605&ll=50.93732845,6.959234323073302&radius=600&limit=15'

# %%
results = requests.get(url).json()

# %%
results
# Out:
# {'meta': {'code': 200, 'requestId': '609810be88a98b3410612ac4'},
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-57fa333d498e66b44a75a041-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'id': '56aa371ce4b08b9a8d57356c',
#          'name': 'Beer Bar',
#          'pluralName': 'Beer Bars',
#          'primary': True,
#          'shortName': 'Beer Bar'}],
#        'id': '57fa333d498e66b44a75a041',
#        'location': {'address': 'Martinstr. 32',
#         'cc': 'DE',
#         'city': 'Köln',
#         'country': 'Deutschland',
#         'crossStreet': 'Marsplatz',
#         'distance': 24,
#         'formattedAddress': ['Martinstr. 32 (Marsplatz)',
#          '50667 Köln',
#          'Deutschland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 50.93722182832159,
#           'lng': 6.958927666244598}],
#         'lat': 50.93722182832159,
#         'lng': 6.958927666244598,
#         'postalCode': '50667',
#         'state': 'Nordrhein-Westfalen'},
#        'name': 'Craftbeer Corner',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '347993640'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b9e9cb9f964a520bdf336e3-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_jazzclub_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e7931735',
#          'name': 'Jazz Club',
#          'pluralName': 'Jazz Clubs',
#          'primary': True,
#          'shortName': 'Jazz Club'}],
#        'id': '4b9e9cb9f964a520bdf336e3',
#        'location': {'address': 'Buttermarkt 37',
#         'cc': 'DE',
#         'city': 'Köln',
#         'country': 'Deutschland',
#         'distance': 219,
#         'formattedAddress': ['Buttermarkt 37', '50667 Köln', 'Deutschland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 50.93788151408496,
#           'lng': 6.962241427839143}],
#         'lat': 50.93788151408496,
#         'lng': 6.962241427839143,
#         'postalCode': '50667',
#         'state': 'Nordrhein-Westfalen'},
#        'name': "Papa Joe's Jazzlokal",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b6d85e9f964a520227a2ce3-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/toys_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f3941735',
#          'name': 'Toy / Game Store',
#          'pluralName': 'Toy / Game Stores',
#          'primary': True,
#          'shortName': 'Toys & Games'}],
#        'id': '4b6d85e9f964a520227a2ce3',
#        'location': {'address': 'Hohe Straße 68-82',
#         'cc': 'DE',
#         'city': 'Köln',
#         'country': 'Deutschland',
#         'distance': 186,
#         'formattedAddress': ['Hohe Straße 68-82', '50667 Köln', 'Deutschland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 50.9370912,
#           'lng': 6.9566049}],
#         'lat': 50.9370912,
#         'lng': 6.9566049,
#         'postalCode': '50667',
#         'state': 'Nordrhein-Westfalen'},
#        'name': 'LEGO Store',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b05886df964a5204bc522e3-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'primary': True,
#          'shortName': 'Plaza'}],
#        'id': '4b05886df964a5204bc522e3',
#        'location': {'address': 'Alter Markt',
#         'cc': 'DE',
#         'city': 'Köln',
#         'country': 'Deutschland',
#         'distance': 155,
#         'formattedAddress': ['Alter Markt', '50667 Köln', 'Deutschland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 50.93862318375552,
#           'lng': 6.960069739472394}],
#         'lat': 50.93862318375552,
#         'lng': 6.960069739472394,
#         'postalCode': '50667',
#         'state': 'Nordrhein-Westfalen'},
#        'name': 'Alter Markt',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b05886df964a5204dc522e3-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'primary': True,
#          'shortName': 'Plaza'}],
#        'id': '4b05886df964a5204dc522e3',
#        'location': {'address': 'Heumarkt',
#         'cc': 'DE',
#         'city': 'Köln',
#         'country': 'Deutschland',
#         'distance': 155,
#         'formattedAddress': ['Heumarkt', '50667 Köln', 'Deutschland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 50.93616079114913,
#           'lng': 6.960461139678955}],
#         'lat': 50.93616079114913,
#         'lng': 6.960461139678955,
#         'postalCode': '50667',
#         'state': 'Nordrhein-Westfalen'},
#        'name': 'Heumarkt',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5293acac498e0ffaf5384b4c-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d122951735',
#          'name': 'Electronics Store',
#          'pluralName': 'Electronics Stores',
#          'primary': True,
#          'shortName': 'Electronics'}],
#        'id': '5293acac498e0ffaf5384b4c',
#        'location': {'address': 'Schildergasse 1-9',
#         'cc': 'DE',
#         'city': 'Köln',
#         'country': 'Deutschland',
#         'distance': 250,
#         'formattedAddress': ['Schildergasse 1-9', '50667 Köln', 'Deutschland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 50.9365515,
#           'lng': 6.9558768}],
#         'lat': 50.9365515,
#         'lng': 6.9558768,
#         'postalCode': '50667',
#         'state': 'Nordrhein-Westfalen'},
#        'name': 'Apple Schildergasse',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-55c4d339498e74d99351eb1f-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/german_',
#           'suffix': '.png'},
#          'id': '56aa371ce4b08b9a8d573572',
#          'name': 'Bavarian Restaurant',
#          'pluralName': 'Bavarian Restaurants',
#          'primary': True,
#          'shortName': 'Bavarian'}],
#        'id': '55c4d339498e74d99351eb1f',
#        'location': {'address': 'Steinweg 12-14',
#         'cc': 'DE',
#         'city': 'Köln',
#         'country': 'Deutschland',
#         'distance': 41,
#         'formattedAddress': ['Steinweg 12-14', 'Köln', 'Deutschland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 50.93742315319849,
#           'lng': 6.959806138223603}],
#         'lat': 50.93742315319849,
#         'lng': 6.959806138223603,
#         'state': 'Nordrhein-Westfalen'},
#        'name': 'Servus Colonia Alpina',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b058869f964a52026c422e3-7',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '4b058869f964a52026c422e3',
#        'location': {'address': 'Pipinstr. 1',
#         'cc': 'DE',
#         'city': 'Köln',
#         'country': 'Deutschland',
#         'distance': 238,
#         'formattedAddress': ['Pipinstr. 1', '50667 Köln', 'Deutschland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 50.93540765903893,
#           'lng': 6.957728565038355}],
#         'lat': 50.93540765903893,
#         'lng': 6.957728565038355,
#         'postalCode': '50667',
#         'state': 'Nordrhein-Westfalen'},
#        'name': 'Dorint Hotel am Heumarkt Köln',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5b0686feee628b002cba16f7-8',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'primary': True,
#          'shortName': 'Ice Cream'}],
#        'id': '5b0686feee628b002cba16f7',
#        'location': {'address': 'Heumarkt 27',
#         'cc': 'DE',
#         'city': 'Köln',
#         'country': 'Deutschland',
#         'distance': 211,
#         'formattedAddress': ['Heumarkt 27', '50667 Köln', 'Deutschland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 50.93552,
#           'lng': 6.96018}],
#         'lat': 50.93552,
#         'lng': 6.96018,
#         'postalCode': '50667',
#         'state': 'Nordrhein-Westfalen'},
#        'name': 'Ice Cream United',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b4ca891f964a52040b926e3-9',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '4b4ca891f964a52040b926e3',
#        'location': {'address': 'Gürzenichstr. 6-16',
#         'cc': 'DE',
#         'city': 'Köln',
#         'country': 'Deutschland',
#         'distance': 168,
#         'formattedAddress': ['Gürzenichstr. 6-16',
#          '50667 Köln',
#          'Deutschland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 50.936252086492686,
#           'lng': 6.957538213927753}],
#         'lat': 50.936252086492686,
#         'lng': 6.957538213927753,
#         'postalCode': '50667',
#         'state': 'Nordrhein-Westfalen'},
#        'name': 'Holmes Place',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b633183f964a52095692ae3-10',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'primary': True,
#          'shortName': 'Steakhouse'}],
#        'id': '4b633183f964a52095692ae3',
#        'location': {'address': 'Bolzengasse 9',
#         'cc': 'DE',
#         'city': 'Köln',
#         'country': 'Deutschland',
#         'distance': 96,
#         'formattedAddress': ['Bolzengasse 9', '50667 Köln', 'Deutschland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 50.936599375726374,
#           'lng': 6.959978105401502}],
#         'lat': 50.936599375726374,
#         'lng': 6.959978105401502,
#         'postalCode': '50667',
#         'state': 'Nordrhein-Westfalen'},
#        'name': 'El Chango',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b05886ff964a520a4c522e3-11',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_art_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d18f941735',
#          'name': 'Art Museum',
#          'pluralName': 'Art Museums',
#          'primary': True,
#          'shortName': 'Art Museum'}],
#        'id': '4b05886ff964a520a4c522e3',
#        'location': {'address': 'Obermarspforten 40',
#         'cc': 'DE',
#         'city': 'Köln',
#         'country': 'Deutschland',
#         'distance': 51,
#         'formattedAddress': ['Obermarspforten 40',
#          '50667 Köln',
#          'Deutschland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 50.937424892019685,
#           'lng': 6.958522869655499}],
#         'lat': 50.937424892019685,
#         'lng': 6.958522869655499,
#         'postalCode': '50667',
#         'state': 'Nordrhein-Westfalen'},
#        'name': 'Wallraf-Richartz-Museum',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5202f81d498e593aca2577de-12',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#           'suffix': '.png'},
#          'id': '52e81612bcbc57f1066b7a25',
#          'name': 'Pedestrian Plaza',
#          'pluralName': 'Pedestrian Plazas',
#          'primary': True,
#          'shortName': 'Pedestrian Street/Plaza'}],
#        'id': '5202f81d498e593aca2577de',
#        'location': {'address': 'Frankenwerft',
#         'cc': 'DE',
#         'city': 'Köln',
#         'country': 'Deutschland',
#         'distance': 304,
#         'formattedAddress': ['Frankenwerft', '50667 Köln', 'Deutschland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 50.93882659733972,
#           'lng': 6.962870027971316}],
#         'lat': 50.93882659733972,
#         'lng': 6.962870027971316,
#         'postalCode': '50667',
#         'state': 'Nordrhein-Westfalen'},
#        'name': 'Rheinufer Altstadt',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c0a93d4bbc676b06f124ad5-13',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'primary': True,
#          'shortName': 'Park'}],
#        'id': '4c0a93d4bbc676b06f124ad5',
#        'location': {'address': 'Frankenwerft',
#         'cc': 'DE',
#         'city': 'Köln',
#         'country': 'Deutschland',
#         'distance': 274,
#         'formattedAddress': ['Frankenwerft', '50667 Köln', 'Deutschland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 50.93824346544839,
#           'lng': 6.962875024765755}],
#         'lat': 50.93824346544839,
#         'lng': 6.962875024765755,
#         'postalCode': '50667',
#         'state': 'Nordrhein-Westfalen'},
#        'name': 'Rheingarten',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b05886df964a5200ac522e3-14',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'primary': True,
#          'shortName': 'Plaza'}],
#        'id': '4b05886df964a5200ac522e3',
#        'location': {'address': 'Fischmarkt',
#         'cc': 'DE',
#         'city': 'Köln',
#         'country': 'Deutschland',
#         'distance': 258,
#         'formattedAddress': ['Fischmarkt', '50667 Köln', 'Deutschland'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 50.938363402263114,
#           'lng': 6.962527371162799}],
#         'lat': 50.938363402263114,
#         'lng': 6.962527371162799,
#         'postalCode': '50667',
#         'state': 'Nordrhein-Westfalen'},
#        'name': 'Fischmarkt',
#        'photos': {'count': 0, 'groups': []}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'Altstadt-Nord, Cologne',
#   'headerLocation': 'Altstadt-Nord',
#   'headerLocationGranularity': 'neighborhood',
#   'suggestedBounds': {'ne': {'lat': 50.94272845540001,
#     'lng': 6.9677874473444525},
#    'sw': {'lat': 50.9319284446, 'lng': 6.950681198802151}},
#   'suggestedFilters': {'filters': [{'key': 'openNow', 'name': 'Open now'}],
#    'header': 'Tap to show:'},
#   'totalResults': 120}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#                    name        categories        lat       lng
# 0      Craftbeer Corner          Beer Bar  50.937222  6.958928
# 1  Papa Joe's Jazzlokal         Jazz Club  50.937882  6.962241
# 2            LEGO Store  Toy / Game Store  50.937091  6.956605
# 3           Alter Markt             Plaza  50.938623  6.960070
# 4              Heumarkt             Plaza  50.936161  6.960461

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 15 venues were returned by Foursquare.

# %%
print ('{} unique categories in Köln-Innenstadt.'.format(nearby_venues['categories'].value_counts().shape[0]))
# Out:
# 13 unique categories in Köln-Innenstadt.

# %%
print (nearby_venues['categories'].value_counts()[0:15])
# Out:
# Plaza                   3
# Jazz Club               1
# Beer Bar                1
# Hotel                   1
# Bavarian Restaurant     1
# Ice Cream Shop          1
# Electronics Store       1
# Pedestrian Plaza        1
# Steakhouse              1
# Toy / Game Store        1
# Gym / Fitness Center    1
# Park                    1
# Art Museum              1
# Name: categories, dtype: int64

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=3000, LIMIT=1000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']

    
    return(nearby_venues)

# %%
Cologne_venues = getNearbyVenues(names=df['City district'],
                                   latitudes=df['Latitude'],
                                   longitudes=df['Longitude']
                                  )
# Out:
# Köln-Innenstadt
# Köln-Rodenkirchen
# Köln-Lindenthal
# Köln-Ehrenfeld
# Köln-Nippes
# Köln-Chorweiler
# Köln-Porz
# Köln-Kalk
# Köln-Mülheim

# %%
Cologne_venues.shape
# Out:
# (759, 7)

# %%
# Create a Data-Frame out of it to concentrate only on Restaurants 
Cologne_Venues_only_restaurant = Cologne_venues[Cologne_venues['Venue Category'].str.contains('Restaurant')].reset_index(drop=True)
Cologne_Venues_only_restaurant.index = np.arange(1, len(Cologne_Venues_only_restaurant )+1)

# %%
print (Cologne_Venues_only_restaurant['Venue Category'].value_counts())
# Out:
# Italian Restaurant               27
# German Restaurant                25
# Restaurant                       15
# Turkish Restaurant               12
# Sushi Restaurant                 11
# Greek Restaurant                 10
# French Restaurant                 9
# Vietnamese Restaurant             7
# Spanish Restaurant                6
# Modern European Restaurant        6
# Japanese Restaurant               4
# Seafood Restaurant                3
# Asian Restaurant                  3
# Mexican Restaurant                3
# Mediterranean Restaurant          3
# Vegetarian / Vegan Restaurant     3
# Middle Eastern Restaurant         3
# Kebab Restaurant                  2
# Falafel Restaurant                2
# Doner Restaurant                  2
# Kurdish Restaurant                2
# Indian Restaurant                 2
# Thai Restaurant                   2
# Israeli Restaurant                2
# Tapas Restaurant                  2
# Fast Food Restaurant              2
# Comfort Food Restaurant           2
# Rhenisch Restaurant               1
# Eastern European Restaurant       1
# Schnitzel Restaurant              1
# Austrian Restaurant               1
# Hungarian Restaurant              1
# Scandinavian Restaurant           1
# American Restaurant               1
# Mongolian Restaurant              1
# Name: Venue Category, dtype: int64

# %%
print('There are {} unique categories.'.format(len(Cologne_Venues_only_restaurant['Venue Category'].unique())))
# Out:
# There are 35 unique categories.

# %%
# create a dataframe of top 10 categories
Cologne_Venues_Top10 = Cologne_Venues_only_restaurant['Venue Category'].value_counts()[0:10].to_frame(name='frequency')
Cologne_Venues_Top10=Cologne_Venues_Top10.reset_index()
Cologne_Venues_Top10.rename(index=str, columns={"index": "Venue_Category", "frequency": "Frequency"}, inplace=True)
Cologne_Venues_Top10
# Out:
#                Venue_Category  Frequency
# 0          Italian Restaurant         27
# 1           German Restaurant         25
# 2                  Restaurant         15
# 3          Turkish Restaurant         12
# 4            Sushi Restaurant         11
# 5            Greek Restaurant         10
# 6           French Restaurant          9
# 7       Vietnamese Restaurant          7
# 8          Spanish Restaurant          6
# 9  Modern European Restaurant          6

# %%
import seaborn as sns
from matplotlib import pyplot as plt

s=sns.barplot(x="Venue_Category", y="Frequency", data=Cologne_Venues_Top10)
s.set_xticklabels(s.get_xticklabels(), rotation=45, horizontalalignment='right')

plt.title('10 Most Frequently Occuring Venues in 9 City Districts of Cologne', fontsize=15)
plt.xlabel("Venue Category", fontsize=15)
plt.ylabel ("Frequency", fontsize=15)
plt.savefig("Most_Freq_Venues1.png", dpi=300)
fig = plt.figure(figsize=(18,7))
plt.show()

# %%
print ("Shape of the Data-Frame with Venue Category only Restaurant: ", Cologne_Venues_only_restaurant.shape)
Cologne_Venues_only_restaurant.head(75)
# Out:
# Shape of the Data-Frame with Venue Category only Restaurant:  (178, 7)
#          Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 1     Köln-Innenstadt              50.937328                6.959234
# 2     Köln-Innenstadt              50.937328                6.959234
# 3     Köln-Innenstadt              50.937328                6.959234
# 4     Köln-Innenstadt              50.937328                6.959234
# 5     Köln-Innenstadt              50.937328                6.959234
# 6     Köln-Innenstadt              50.937328                6.959234
# 7     Köln-Innenstadt              50.937328                6.959234
# 8     Köln-Innenstadt              50.937328                6.959234
# 9     Köln-Innenstadt              50.937328                6.959234
# 10    Köln-Innenstadt              50.937328                6.959234
# 11    Köln-Innenstadt              50.937328                6.959234
# 12    Köln-Innenstadt              50.937328                6.959234
# 13    Köln-Innenstadt              50.937328                6.959234
# 14    Köln-Innenstadt              50.937328                6.959234
# 15    Köln-Innenstadt              50.937328                6.959234
# 16    Köln-Innenstadt              50.937328                6.959234
# 71                        Habibi       50.929504         6.937835
# 72      Mashery - Hummus Kitchen       50.931171         6.937651
# 73                        Sonder       50.931811         6.932872
# 74                    Einheit 15       50.964993         6.952250
# 75                Le Moissonnier       50.950796         6.952466
#
#                    Venue Category
# 1   Vegetarian / Vegan Restaurant
# 2                Sushi Restaurant
# 3             Rhenisch Restaurant
# 4           Vietnamese Restaurant
# 5                Sushi Restaurant
# 6           Vietnamese Restaurant
# 7                      Restaurant
# 8            Hungarian Restaurant
# 9      Modern European Restaurant
# 10             Italian Restaurant
# 11              German Restaurant
# 12              French Restaurant
# 13      Middle Eastern Restaurant
# 14     Modern European Restaurant
# 15             Falafel Restaurant
# 16             Italian Restaurant
# 17           Schnitzel Restaurant
# 18             Italian Restaurant
# 19             Italian Restaurant
# 20             Spanish Restaurant
# 21              French Restaurant
# 22             Israeli Restaurant
# 23            Japanese Restaurant
# 24              German Restaurant
# 25               Tapas Restaurant
# 26          Vietnamese Restaurant
# 27        Scandinavian Restaurant
# 28              German Restaurant
# 29             Italian Restaurant
# 30              German Restaurant
# 31             Italian Restaurant
# 32              German Restaurant
# 33               Sushi Restaurant
# 34                     Restaurant
# 35               Sushi Restaurant
# 36             Mexican Restaurant
# 37            Japanese Restaurant
# 38               Greek Restaurant
# 39                     Restaurant
# 40              German Restaurant
# 41              German Restaurant
# 42               Greek Restaurant
# 43              German Restaurant
# 44     Modern European Restaurant
# 45              French Restaurant
# 46              German Restaurant
# 47               Sushi Restaurant
# 48            American Restaurant
# 49              Indian Restaurant
# 50                     Restaurant
# 51               Kebab Restaurant
# 52                     Restaurant
# 53              German Restaurant
# 54             Turkish Restaurant
# 55             Spanish Restaurant
# 56             Italian Restaurant
# 57          Vietnamese Restaurant
# 58             Italian Restaurant
# 59             Spanish Restaurant
# 60     Modern European Restaurant
# 61            Japanese Restaurant
# 62             Italian Restaurant
# 63               Sushi Restaurant
# 64               Tapas Restaurant
# 65                     Restaurant
# 66              French Restaurant
# 67               Sushi Restaurant
# 68                     Restaurant
# 69              German Restaurant
# 70            Japanese Restaurant
# 71             Falafel Restaurant
# 72             Israeli Restaurant
# 73              German Restaurant
# 74     Modern European Restaurant
# 75              French Restaurant

# %%
Cologne_Venues_restaurant = Cologne_Venues_only_restaurant.groupby(['Neighborhood'])['Venue Category'].apply(lambda x: x[x.str.contains('Restaurant')].count())

# %% [markdown]
# Analysis of the neighbourhoods.

# %%
Cologne_Venues_restaurant
# Out:
# Neighborhood
# Köln-Chorweiler       3
# Köln-Ehrenfeld       23
# Köln-Innenstadt      26
# Köln-Kalk            25
# Köln-Lindenthal      22
# Köln-Mülheim         21
# Köln-Nippes          29
# Köln-Porz            27
# Köln-Rodenkirchen     2
# Name: Venue Category, dtype: int64

# %%
Cologne_Venues_restaurant_df  = Cologne_Venues_restaurant.to_frame().reset_index()
Cologne_Venues_restaurant_df.columns = ['Neighborhood', 'Number of Restaurant']
Cologne_Venues_restaurant_df.index = np.arange(1, len(Cologne_Venues_restaurant_df)+1)
list_rest_no =Cologne_Venues_restaurant_df['Number of Restaurant'].to_list()
list_dist =Cologne_Venues_restaurant_df['Neighborhood'].to_list()

# %%
# one hot encoding
Cologne_onehot = pd.get_dummies(Cologne_Venues_only_restaurant[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
restaurant  Tapas Restaurant  Thai Restaurant  \
# 0            0.000000          0.333333          0.000000         0.000000
# 1            0.086957          0.086957          0.043478         0.000000
# 2            0.038462          0.076923          0.038462         0.000000
# 3            0.040000          0.000000          0.000000         0.000000
# 4            0.000000          0.136364          0.000000         0.000000
# 5            0.000000          0.000000          0.000000         0.000000
# 6            0.068966          0.068966          0.000000         0.034483
# 7            0.000000          0.037037          0.000000         0.037037
# 8            0.000000          0.000000          0.000000         0.000000
#
#    Turkish Restaurant  Vegetarian / Vegan Restaurant  Vietnamese Restaurant
# 0            0.000000                       0.000000               0.000000
# 1            0.043478                       0.000000               0.043478
# 2            0.000000                       0.038462               0.115385
# 3            0.040000                       0.040000               0.040000
# 4            0.000000                       0.000000               0.000000
# 5            0.380952                       0.047619               0.047619
# 6            0.034483                       0.000000               0.034483
# 7            0.037037                       0.000000               0.000000
# 8            0.000000                       0.000000               0.000000

# %%
Cologne_grouped.shape
# Out:
# (9, 36)

# %%
num_top_venues = 10

for hood in Cologne_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = Cologne_grouped[Cologne_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Köln-Chorweiler----
#                         venue  freq
# 0          Italian Restaurant  0.33
# 1            Sushi Restaurant  0.33
# 2        Fast Food Restaurant  0.33
# 3         American Restaurant  0.00
# 4        Schnitzel Restaurant  0.00
# 5  Modern European Restaurant  0.00
# 6        Mongolian Restaurant  0.00
# 7                  Restaurant  0.00
# 8         Rhenisch Restaurant  0.00
# 9     Scandinavian Restaurant  0.00
#
#
# ----Köln-Ehrenfeld----
#                         venue  freq
# 0           German Restaurant  0.13
# 1                  Restaurant  0.13
# 2          Italian Restaurant  0.13
# 3          Spanish Restaurant  0.09
# 4         Japanese Restaurant  0.09
# 5            Sushi Restaurant  0.09
# 6            Kebab Restaurant  0.04
# 7          Israeli Restaurant  0.04
# 8  Modern European Restaurant  0.04
# 9       Vietnamese Restaurant  0.04
#
#
# ----Köln-Innenstadt----
#                         venue  freq
# 0          Italian Restaurant  0.15
# 1       Vietnamese Restaurant  0.12
# 2            Sushi Restaurant  0.08
# 3           German Restaurant  0.08
# 4           French Restaurant  0.08
# 5  Modern European Restaurant  0.08
# 6          Falafel Restaurant  0.04
# 7            Tapas Restaurant  0.04
# 8          Spanish Restaurant  0.04
# 9          Israeli Restaurant  0.04
#
#
# ----Köln-Kalk----
#                            venue  freq
# 0                     Restaurant  0.16
# 1             Italian Restaurant  0.12
# 2               Greek Restaurant  0.08
# 3             Kurdish Restaurant  0.04
# 4  Vegetarian / Vegan Restaurant  0.04
# 5             Turkish Restaurant  0.04
# 6             Spanish Restaurant  0.04
# 7           Mongolian Restaurant  0.04
# 8     Modern European Restaurant  0.04
# 9      Middle Eastern Restaurant  0.04
#
#
# ----Köln-Lindenthal----
#                         venue  freq
# 0           German Restaurant  0.27
# 1                  Restaurant  0.14
# 2            Sushi Restaurant  0.14
# 3            Greek Restaurant  0.09
# 4          Italian Restaurant  0.09
# 5          Mexican Restaurant  0.05
# 6         Japanese Restaurant  0.05
# 7           Indian Restaurant  0.05
# 8  Modern European Restaurant  0.05
# 9         American Restaurant  0.05
#
#
# ----Köln-Mülheim----
#                            venue  freq
# 0             Turkish Restaurant  0.38
# 1       Mediterranean Restaurant  0.10
# 2               Asian Restaurant  0.10
# 3             Italian Restaurant  0.10
# 4          Vietnamese Restaurant  0.05
# 5              German Restaurant  0.05
# 6             Seafood Restaurant  0.05
# 7               Greek Restaurant  0.05
# 8        Comfort Food Restaurant  0.05
# 9  Vegetarian / Vegan Restaurant  0.05
#
#
# ----Köln-Nippes----
#                         venue  freq
# 0          Italian Restaurant  0.24
# 1           German Restaurant  0.14
# 2            Greek Restaurant  0.10
# 3           French Restaurant  0.10
# 4          Spanish Restaurant  0.07
# 5            Sushi Restaurant  0.07
# 6                  Restaurant  0.03
# 7            Kebab Restaurant  0.03
# 8  Modern European Restaurant  0.03
# 9       Vietnamese Restaurant  0.03
#
#
# ----Köln-Porz----
#                   venue  freq
# 0     German Restaurant  0.26
# 1    Italian Restaurant  0.19
# 2            Restaurant  0.11
# 3      Greek Restaurant  0.07
# 4    Seafood Restaurant  0.07
# 5     French Restaurant  0.07
# 6  Fast Food Restaurant  0.04
# 7    Kurdish Restaurant  0.04
# 8      Sushi Restaurant  0.04
# 9       Thai Restaurant  0.04
#
#
# ----Köln-Rodenkirchen----
#                         venue  freq
# 0           German Restaurant   0.5
# 1     Scandinavian Restaurant   0.5
# 2    Mediterranean Restaurant   0.0
# 3   Middle Eastern Restaurant   0.0
# 4  Modern European Restaurant   0.0
# 5        Mongolian Restaurant   0.0
# 6                  Restaurant   0.0
# 7         Rhenisch Restaurant   0.0
# 8        Schnitzel Restaurant   0.0
# 9         American Restaurant   0.0

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = Cologne_grouped['Neighborhood']

for ind in np.arange(Cologne_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(Cologne_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head(23)
# Out:
#         Neighborhood    1st Most Common Venue  2nd Most Common Venue  \
# 0    Köln-Chorweiler     Fast Food Restaurant     Italian Restaurant
# 1     Köln-Ehrenfeld               Restaurant     Italian Restaurant
# 2    Köln-Innenstadt       Italian Restaurant  Vietnamese Restaurant
# 3          Köln-Kalk               Restaurant     Italian Restaurant
# 4    Köln-Lindenthal        German Restaurant       Sushi Restaurant
# 5       Köln-Mülheim       Turkish Restaurant       Asian Restaurant
# 6        Köln-Nippes       Italian Restaurant      German Restaurant
# 7          Köln-Porz        German Restaurant     Italian Restaurant
# 8  Köln-Rodenkirchen  Scandinavian Restaurant      German Restaurant
#
#         3rd Most Common Venue  4th Most Common Venue  \
# 0            Sushi Restaurant      French Restaurant
# 1           German Restaurant    Japanese Restaurant
# 2  Modern European Restaurant      German Restaurant
# 3            Greek Restaurant  Vietnamese Restaurant
# 4                  Restaurant     Italian Restaurant
# 5    Mediterranean Restaurant     Italian Restaurant
# 6            Greek Restaurant      French Restaurant
# 7                  Restaurant       Greek Restaurant
# 8            Kebab Restaurant     Italian Restaurant
#
#        5th Most Common Venue 6th Most Common Venue    7th Most Common Venue  \
# 0         Israeli Restaurant     Indian Restaurant     Hungarian Restaurant
# 1           Sushi Restaurant    Spanish Restaurant       Falafel Restaurant
# 2           Sushi Restaurant     French Restaurant       Israeli Restaurant
# 3  Middle Eastern Restaurant      Asian Restaurant  Comfort Food Restaurant
# 4           Greek Restaurant   American Restaurant        Indian Restaurant
# 5      Vietnamese Restaurant      Greek Restaurant  Comfort Food Restaurant
# 6           Sushi Restaurant    Spanish Restaurant               Restaurant
# 7          French Restaurant    Seafood Restaurant       Mexican Restaurant
# 8         Israeli Restaurant     Indian Restaurant     Hungarian Restaurant
#
#            8th Most Common Venue          9th Most Common Venue  \
# 0               Greek Restaurant              German Restaurant
# 1               Kebab Restaurant              French Restaurant
# 2            Japanese Restaurant  Vegetarian / Vegan Restaurant
# 3               Doner Restaurant    Eastern European Restaurant
# 4             Mexican Restaurant     Modern European Restaurant
# 5  Vegetarian / Vegan Restaurant             Seafood Restaurant
# 6               Kebab Restaurant     Modern European Restaurant
# 7           Fast Food Restaurant             Kurdish Restaurant
# 8               Greek Restaurant              French Restaurant
#
#        10th Most Common Venue
# 0       Vietnamese Restaurant
# 1  Modern European Restaurant
# 2          Falafel Restaurant
# 3           German Restaurant
# 4           French Restaurant
# 5   Middle Eastern Restaurant
# 6       Vietnamese Restaurant
# 7            Sushi Restaurant
# 8       Vietnamese Restaurant

# %% [markdown]
# Clustering it with k-means

# %%
# set number of clusters (I choose 5)
kclusters = 5

Cologne_grouped_clustering = Cologne_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(Cologne_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([2, 4, 4, 4, 0, 3, 4, 0, 1], dtype=int32)

# %%
Cologne_merged = df
Cologne_merged.head(10)
# Out:
#        City district                                         City parts  \
# 0    Köln-Innenstadt  Altstadt-Nord, Altstadt-Süd, Deutz, Neustadt-N...
# 1  Köln-Rodenkirchen  Bayenthal, Godorf, Hahnwald, Immendorf, Marien...
# 2    Köln-Lindenthal  Braunsfeld, Junkersdorf, Klettenberg, Lindenth...
# 3     Köln-Ehrenfeld  Bickendorf, Bocklemünd/Mengenich, Ehrenfeld, N...
# 4        Köln-Nippes  Bilderstöckchen, Longerich, Mauenheim, Niehl, ...
# 5    Köln-Chorweiler  Blumenberg, Chorweiler, Esch/Auweiler, Fühling...
# 6          Köln-Porz  Eil, Elsdorf, Ensen, Finkenberg, Gremberghoven...
# 7          Köln-Kalk  Brück, Höhenberg, Humboldt/Gremberg, Kalk, Mer...
# 8       Köln-Mülheim  Buchforst, Buchheim, Dellbrück, Dünnwald, Flit...
#
#        Area Population1 Pop. density  \
# 0  16.4 km²     127.033    7.746/km²
# 1  54.6 km²     100.936    1.850/km²
# 2  41.6 km²     137.552    3.308/km²
# 3  23.8 km²     103.621    4.348/km²
# 4  31.8 km²     110.092    3.462/km²
# 5  67.2 km²      80.870    1.204/km²
# 6  78.8 km²     106.520    1.352/km²
# 7  38.2 km²     108.330    2.841/km²
# 8  52.2 km²     144.374    2.764/km²
#
#                                    District Councils   Latitude  Longitude
# 0  Bezirksksamt Innenstadt Brückenstraße 19, D-50...  50.937328   6.959234
# 1  Bezirksamt Rodenkirchen Hauptstraße 85, D-5099...  50.865622   6.969718
# 2  Bezirksamt Lindenthal Aachener Straße 220, 509...  50.935935   6.871246
# 3  Bezirksamt Ehrenfeld Venloer Straße 419 – 421,...  50.951502   6.916529
# 4   Bezirksamt NippesNeusser Straße 450,D-50733 Köln  50.958994   6.941777
# 5  Bezirksamt Chorweiler Pariser Platz 1, D-50765...  51.021167   6.898034
# 6  Bezirksamt PorzFriedrich-Ebert-Ufer 64–70, D-5...  50.906705   6.999129
# 7  Bezirksamt KalkKalker Hauptstraße 247–273,D-51...  50.931923   7.005806
# 8    Bezirksamt Mülheim Wiener Platz 2a,D-51065 Köln  50.958147   7.013526

# %%
neighborhoods_venues_sorted.head(23)
# Out:
#         Neighborhood    1st Most Common Venue  2nd Most Common Venue  \
# 0    Köln-Chorweiler     Fast Food Restaurant     Italian Restaurant
# 1     Köln-Ehrenfeld               Restaurant     Italian Restaurant
# 2    Köln-Innenstadt       Italian Restaurant  Vietnamese Restaurant
# 3          Köln-Kalk               Restaurant     Italian Restaurant
# 4    Köln-Lindenthal        German Restaurant       Sushi Restaurant
# 5       Köln-Mülheim       Turkish Restaurant       Asian Restaurant
# 6        Köln-Nippes       Italian Restaurant      German Restaurant
# 7          Köln-Porz        German Restaurant     Italian Restaurant
# 8  Köln-Rodenkirchen  Scandinavian Restaurant      German Restaurant
#
#         3rd Most Common Venue  4th Most Common Venue  \
# 0            Sushi Restaurant      French Restaurant
# 1           German Restaurant    Japanese Restaurant
# 2  Modern European Restaurant      German Restaurant
# 3            Greek Restaurant  Vietnamese Restaurant
# 4                  Restaurant     Italian Restaurant
# 5    Mediterranean Restaurant     Italian Restaurant
# 6            Greek Restaurant      French Restaurant
# 7                  Restaurant       Greek Restaurant
# 8            Kebab Restaurant     Italian Restaurant
#
#        5th Most Common Venue 6th Most Common Venue    7th Most Common Venue  \
# 0         Israeli Restaurant     Indian Restaurant     Hungarian Restaurant
# 1           Sushi Restaurant    Spanish Restaurant       Falafel Restaurant
# 2           Sushi Restaurant     French Restaurant       Israeli Restaurant
# 3  Middle Eastern Restaurant      Asian Restaurant  Comfort Food Restaurant
# 4           Greek Restaurant   American Restaurant        Indian Restaurant
# 5      Vietnamese Restaurant      Greek Restaurant  Comfort Food Restaurant
# 6           Sushi Restaurant    Spanish Restaurant               Restaurant
# 7          French Restaurant    Seafood Restaurant       Mexican Restaurant
# 8         Israeli Restaurant     Indian Restaurant     Hungarian Restaurant
#
#            8th Most Common Venue          9th Most Common Venue  \
# 0               Greek Restaurant              German Restaurant
# 1               Kebab Restaurant              French Restaurant
# 2            Japanese Restaurant  Vegetarian / Vegan Restaurant
# 3               Doner Restaurant    Eastern European Restaurant
# 4             Mexican Restaurant     Modern European Restaurant
# 5  Vegetarian / Vegan Restaurant             Seafood Restaurant
# 6               Kebab Restaurant     Modern European Restaurant
# 7           Fast Food Restaurant             Kurdish Restaurant
# 8               Greek Restaurant              French Restaurant
#
#        10th Most Common Venue
# 0       Vietnamese Restaurant
# 1  Modern European Restaurant
# 2          Falafel Restaurant
# 3           German Restaurant
# 4           French Restaurant
# 5   Middle Eastern Restaurant
# 6       Vietnamese Restaurant
# 7            Sushi Restaurant
# 8       Vietnamese Restaurant

# %%
neighborhoods_venues_sorted_w_clusters = neighborhoods_venues_sorted

# %%
neighborhoods_venues_sorted_w_clusters.head(9)
# Out:
#         Neighborhood    1st Most Common Venue  2nd Most Common Venue  \
# 0    Köln-Chorweiler     Fast Food Restaurant     Italian Restaurant
# 1     Köln-Ehrenfeld               Restaurant     Italian Restaurant
# 2    Köln-Innenstadt       Italian Restaurant  Vietnamese Restaurant
# 3          Köln-Kalk               Restaurant     Italian Restaurant
# 4    Köln-Lindenthal        German Restaurant       Sushi Restaurant
# 5       Köln-Mülheim       Turkish Restaurant       Asian Restaurant
# 6        Köln-Nippes       Italian Restaurant      German Restaurant
# 7          Köln-Porz        German Restaurant     Italian Restaurant
# 8  Köln-Rodenkirchen  Scandinavian Restaurant      German Restaurant
#
#         3rd Most Common Venue  4th Most Common Venue  \
# 0            Sushi Restaurant      French Restaurant
# 1           German Restaurant    Japanese Restaurant
# 2  Modern European Restaurant      German Restaurant
# 3            Greek Restaurant  Vietnamese Restaurant
# 4                  Restaurant     Italian Restaurant
# 5    Mediterranean Restaurant     Italian Restaurant
# 6            Greek Restaurant      French Restaurant
# 7                  Restaurant       Greek Restaurant
# 8            Kebab Restaurant     Italian Restaurant
#
#        5th Most Common Venue 6th Most Common Venue    7th Most Common Venue  \
# 0         Israeli Restaurant     Indian Restaurant     Hungarian Restaurant
# 1           Sushi Restaurant    Spanish Restaurant       Falafel Restaurant
# 2           Sushi Restaurant     French Restaurant       Israeli Restaurant
# 3  Middle Eastern Restaurant      Asian Restaurant  Comfort Food Restaurant
# 4           Greek Restaurant   American Restaurant        Indian Restaurant
# 5      Vietnamese Restaurant      Greek Restaurant  Comfort Food Restaurant
# 6           Sushi Restaurant    Spanish Restaurant               Restaurant
# 7          French Restaurant    Seafood Restaurant       Mexican Restaurant
# 8         Israeli Restaurant     Indian Restaurant     Hungarian Restaurant
#
#            8th Most Common Venue          9th Most Common Venue  \
# 0               Greek Restaurant              German Restaurant
# 1               Kebab Restaurant              French Restaurant
# 2            Japanese Restaurant  Vegetarian / Vegan Restaurant
# 3               Doner Restaurant    Eastern European Restaurant
# 4             Mexican Restaurant     Modern European Restaurant
# 5  Vegetarian / Vegan Restaurant             Seafood Restaurant
# 6               Kebab Restaurant     Modern European Restaurant
# 7           Fast Food Restaurant             Kurdish Restaurant
# 8               Greek Restaurant              French Restaurant
#
#        10th Most Common Venue
# 0       Vietnamese Restaurant
# 1  Modern European Restaurant
# 2          Falafel Restaurant
# 3           German Restaurant
# 4           French Restaurant
# 5   Middle Eastern Restaurant
# 6       Vietnamese Restaurant
# 7            Sushi Restaurant
# 8       Vietnamese Restaurant

# %%
# add clustering labels
neighborhoods_venues_sorted_w_clusters.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
neighborhoods_venues_sorted_w_clusters.head(23)
# Out:
#    Cluster Labels       Neighborhood    1st Most Common Venue  \
# 0               2    Köln-Chorweiler     Fast Food Restaurant
# 1               4     Köln-Ehrenfeld               Restaurant
# 2               4    Köln-Innenstadt       Italian Restaurant
# 3               4          Köln-Kalk               Restaurant
# 4               0    Köln-Lindenthal        German Restaurant
# 5               3       Köln-Mülheim       Turkish Restaurant
# 6               4        Köln-Nippes       Italian Restaurant
# 7               0          Köln-Porz        German Restaurant
# 8               1  Köln-Rodenkirchen  Scandinavian Restaurant
#
#    2nd Most Common Venue       3rd Most Common Venue  4th Most Common Venue  \
# 0     Italian Restaurant            Sushi Restaurant      French Restaurant
# 1     Italian Restaurant           German Restaurant    Japanese Restaurant
# 2  Vietnamese Restaurant  Modern European Restaurant      German Restaurant
# 3     Italian Restaurant            Greek Restaurant  Vietnamese Restaurant
# 4       Sushi Restaurant                  Restaurant     Italian Restaurant
# 5       Asian Restaurant    Mediterranean Restaurant     Italian Restaurant
# 6      German Restaurant            Greek Restaurant      French Restaurant
# 7     Italian Restaurant                  Restaurant       Greek Restaurant
# 8      German Restaurant            Kebab Restaurant     Italian Restaurant
#
#        5th Most Common Venue 6th Most Common Venue    7th Most Common Venue  \
# 0         Israeli Restaurant     Indian Restaurant     Hungarian Restaurant
# 1           Sushi Restaurant    Spanish Restaurant       Falafel Restaurant
# 2           Sushi Restaurant     French Restaurant       Israeli Restaurant
# 3  Middle Eastern Restaurant      Asian Restaurant  Comfort Food Restaurant
# 4           Greek Restaurant   American Restaurant        Indian Restaurant
# 5      Vietnamese Restaurant      Greek Restaurant  Comfort Food Restaurant
# 6           Sushi Restaurant    Spanish Restaurant               Restaurant
# 7          French Restaurant    Seafood Restaurant       Mexican Restaurant
# 8         Israeli Restaurant     Indian Restaurant     Hungarian Restaurant
#
#            8th Most Common Venue          9th Most Common Venue  \
# 0               Greek Restaurant              German Restaurant
# 1               Kebab Restaurant              French Restaurant
# 2            Japanese Restaurant  Vegetarian / Vegan Restaurant
# 3               Doner Restaurant    Eastern European Restaurant
# 4             Mexican Restaurant     Modern European Restaurant
# 5  Vegetarian / Vegan Restaurant             Seafood Restaurant
# 6               Kebab Restaurant     Modern European Restaurant
# 7           Fast Food Restaurant             Kurdish Restaurant
# 8               Greek Restaurant              French Restaurant
#
#        10th Most Common Venue
# 0       Vietnamese Restaurant
# 1  Modern European Restaurant
# 2          Falafel Restaurant
# 3           German Restaurant
# 4           French Restaurant
# 5   Middle Eastern Restaurant
# 6       Vietnamese Restaurant
# 7            Sushi Restaurant
# 8       Vietnamese Restaurant

# %%
Cologne_merged.rename(columns={'City district':'Neighborhood'}, inplace=True)

Cologne_merged = Cologne_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

Cologne_merged.head(10)
# Out:
#         Neighborhood                                         City parts  \
# 0    Köln-Innenstadt  Altstadt-Nord, Altstadt-Süd, Deutz, Neustadt-N...
# 1  Köln-Rodenkirchen  Bayenthal, Godorf, Hahnwald, Immendorf, Marien...
# 2    Köln-Lindenthal  Braunsfeld, Junkersdorf, Klettenberg, Lindenth...
# 3     Köln-Ehrenfeld  Bickendorf, Bocklemünd/Mengenich, Ehrenfeld, N...
# 4        Köln-Nippes  Bilderstöckchen, Longerich, Mauenheim, Niehl, ...
# 5    Köln-Chorweiler  Blumenberg, Chorweiler, Esch/Auweiler, Fühling...
# 6          Köln-Porz  Eil, Elsdorf, Ensen, Finkenberg, Gremberghoven...
# 7          Köln-Kalk  Brück, Höhenberg, Humboldt/Gremberg, Kalk, Mer...
# 8       Köln-Mülheim  Buchforst, Buchheim, Dellbrück, Dünnwald, Flit...
#
#        Area Population1 Pop. density  \
# 0  16.4 km²     127.033    7.746/km²
# 1  54.6 km²     100.936    1.850/km²
# 2  41.6 km²     137.552    3.308/km²
# 3  23.8 km²     103.621    4.348/km²
# 4  31.8 km²     110.092    3.462/km²
# 5  67.2 km²      80.870    1.204/km²
# 6  78.8 km²     106.520    1.352/km²
# 7  38.2 km²     108.330    2.841/km²
# 8  52.2 km²     144.374    2.764/km²
#
#                                    District Councils   Latitude  Longitude  \
# 0  Bezirksksamt Innenstadt Brückenstraße 19, D-50...  50.937328   6.959234
# 1  Bezirksamt Rodenkirchen Hauptstraße 85, D-5099...  50.865622   6.969718
# 2  Bezirksamt Lindenthal Aachener Straße 220, 509...  50.935935   6.871246
# 3  Bezirksamt Ehrenfeld Venloer Straße 419 – 421,...  50.951502   6.916529
# 4   Bezirksamt NippesNeusser Straße 450,D-50733 Köln  50.958994   6.941777
# 5  Bezirksamt Chorweiler Pariser Platz 1, D-50765...  51.021167   6.898034
# 6  Bezirksamt PorzFriedrich-Ebert-Ufer 64–70, D-5...  50.906705   6.999129
# 7  Bezirksamt KalkKalker Hauptstraße 247–273,D-51...  50.931923   7.005806
# 8    Bezirksamt Mülheim Wiener Platz 2a,D-51065 Köln  50.958147   7.013526
#
#    Cluster Labels    1st Most Common Venue  2nd Most Common Venue  \
# 0               4       Italian Restaurant  Vietnamese Restaurant
# 1               1  Scandinavian Restaurant      German Restaurant
# 2               0        German Restaurant       Sushi Restaurant
# 3               4               Restaurant     Italian Restaurant
# 4               4       Italian Restaurant      German Restaurant
# 5               2     Fast Food Restaurant     Italian Restaurant
# 6               0        German Restaurant     Italian Restaurant
# 7               4               Restaurant     Italian Restaurant
# 8               3       Turkish Restaurant       Asian Restaurant
#
#         3rd Most Common Venue  4th Most Common Venue  \
# 0  Modern European Restaurant      German Restaurant
# 1            Kebab Restaurant     Italian Restaurant
# 2                  Restaurant     Italian Restaurant
# 3           German Restaurant    Japanese Restaurant
# 4            Greek Restaurant      French Restaurant
# 5            Sushi Restaurant      French Restaurant
# 6                  Restaurant       Greek Restaurant
# 7            Greek Restaurant  Vietnamese Restaurant
# 8    Mediterranean Restaurant     Italian Restaurant
#
#        5th Most Common Venue 6th Most Common Venue    7th Most Common Venue  \
# 0           Sushi Restaurant     French Restaurant       Israeli Restaurant
# 1         Israeli Restaurant     Indian Restaurant     Hungarian Restaurant
# 2           Greek Restaurant   American Restaurant        Indian Restaurant
# 3           Sushi Restaurant    Spanish Restaurant       Falafel Restaurant
# 4           Sushi Restaurant    Spanish Restaurant               Restaurant
# 5         Israeli Restaurant     Indian Restaurant     Hungarian Restaurant
# 6          French Restaurant    Seafood Restaurant       Mexican Restaurant
# 7  Middle Eastern Restaurant      Asian Restaurant  Comfort Food Restaurant
# 8      Vietnamese Restaurant      Greek Restaurant  Comfort Food Restaurant
#
#            8th Most Common Venue          9th Most Common Venue  \
# 0            Japanese Restaurant  Vegetarian / Vegan Restaurant
# 1               Greek Restaurant              French Restaurant
# 2             Mexican Restaurant     Modern European Restaurant
# 3               Kebab Restaurant              French Restaurant
# 4               Kebab Restaurant     Modern European Restaurant
# 5               Greek Restaurant              German Restaurant
# 6           Fast Food Restaurant             Kurdish Restaurant
# 7               Doner Restaurant    Eastern European Restaurant
# 8  Vegetarian / Vegan Restaurant             Seafood Restaurant
#
#        10th Most Common Venue
# 0          Falafel Restaurant
# 1       Vietnamese Restaurant
# 2           French Restaurant
# 3  Modern European Restaurant
# 4       Vietnamese Restaurant
# 5       Vietnamese Restaurant
# 6            Sushi Restaurant
# 7           German Restaurant
# 8   Middle Eastern Restaurant

# %%
# create a map with folium
map_restaurants10 = folium.Map(location=[latitude,longitude], tiles='cartodbpositron', 
                               attr="<a href=https://github.com/python-visualization/folium/>Folium</a>")

# set color scheme for the five clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
for lat, lon, poi, cluster in zip(Cologne_merged['Latitude'], 
                                  Cologne_merged['Longitude'], 
                                  Cologne_merged['Neighborhood'], 
                                  Cologne_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=list_rest_no[list_dist.index(poi)]*0.5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_restaurants10)
       
map_restaurants10
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_4d39c03bad1c437e9706df2758e79d57%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_4d39c03bad1c437e9706df2758e79d57%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_4d39c03bad1c437e9706df2758e79d57%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_4d39c03bad1c437e9706df2758e79d57%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B50.938361%2C%206.959974%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_7a2809769ab74eb3b8e7bca71ff21f4d%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//cartodb-basemaps-%7Bs%7D.global.ssl.fastly.net/light_all/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20% ...

# %% [markdown]
# Divide it into clusters

# %% [markdown]
# Cluster 1

# %%
Cologne_merged.loc[Cologne_merged['Cluster Labels'] == 0, Cologne_merged.columns[[1] + list(range(5, Cologne_merged.shape[1]))]]
# Out:
#                                           City parts  \
# 2  Braunsfeld, Junkersdorf, Klettenberg, Lindenth...
# 6  Eil, Elsdorf, Ensen, Finkenberg, Gremberghoven...
#
#                                    District Councils   Latitude  Longitude  \
# 2  Bezirksamt Lindenthal Aachener Straße 220, 509...  50.935935   6.871246
# 6  Bezirksamt PorzFriedrich-Ebert-Ufer 64–70, D-5...  50.906705   6.999129
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 2               0     German Restaurant      Sushi Restaurant
# 6               0     German Restaurant    Italian Restaurant
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 2            Restaurant    Italian Restaurant      Greek Restaurant
# 6            Restaurant      Greek Restaurant     French Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 2   American Restaurant     Indian Restaurant    Mexican Restaurant
# 6    Seafood Restaurant    Mexican Restaurant  Fast Food Restaurant
#
#         9th Most Common Venue 10th Most Common Venue
# 2  Modern European Restaurant      French Restaurant
# 6          Kurdish Restaurant       Sushi Restaurant

# %% [markdown]
# This is German Restaurant cluster

# %% [markdown]
# Cluster 2

# %%
Cologne_merged.loc[Cologne_merged['Cluster Labels'] == 1, Cologne_merged.columns[[1] + list(range(5, Cologne_merged.shape[1]))]]
# Out:
#                                           City parts  \
# 1  Bayenthal, Godorf, Hahnwald, Immendorf, Marien...
#
#                                    District Councils   Latitude  Longitude  \
# 1  Bezirksamt Rodenkirchen Hauptstraße 85, D-5099...  50.865622   6.969718
#
#    Cluster Labels    1st Most Common Venue 2nd Most Common Venue  \
# 1               1  Scandinavian Restaurant     German Restaurant
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 1      Kebab Restaurant    Italian Restaurant    Israeli Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 1     Indian Restaurant  Hungarian Restaurant      Greek Restaurant
#
#   9th Most Common Venue 10th Most Common Venue
# 1     French Restaurant  Vietnamese Restaurant

# %% [markdown]
# This is Scandinavian Restaurant cluster

# %% [markdown]
# Cluster 3

# %%
Cologne_merged.loc[Cologne_merged['Cluster Labels'] == 2, Cologne_merged.columns[[1] + list(range(5, Cologne_merged.shape[1]))]]
# Out:
#                                           City parts  \
# 5  Blumenberg, Chorweiler, Esch/Auweiler, Fühling...
#
#                                    District Councils   Latitude  Longitude  \
# 5  Bezirksamt Chorweiler Pariser Platz 1, D-50765...  51.021167   6.898034
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 5               2  Fast Food Restaurant    Italian Restaurant
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 5      Sushi Restaurant     French Restaurant    Israeli Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 5     Indian Restaurant  Hungarian Restaurant      Greek Restaurant
#
#   9th Most Common Venue 10th Most Common Venue
# 5     German Restaurant  Vietnamese Restaurant

# %% [markdown]
# This is fast food restaurant cluster

# %% [markdown]
# Cluster 4

# %%
Cologne_merged.loc[Cologne_merged['Cluster Labels'] == 3, Cologne_merged.columns[[1] + list(range(5, Cologne_merged.shape[1]))]]
# Out:
#                                           City parts  \
# 8  Buchforst, Buchheim, Dellbrück, Dünnwald, Flit...
#
#                                  District Councils   Latitude  Longitude  \
# 8  Bezirksamt Mülheim Wiener Platz 2a,D-51065 Köln  50.958147   7.013526
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 8               3    Turkish Restaurant      Asian Restaurant
#
#       3rd Most Common Venue 4th Most Common Venue  5th Most Common Venue  \
# 8  Mediterranean Restaurant    Italian Restaurant  Vietnamese Restaurant
#
#   6th Most Common Venue    7th Most Common Venue  \
# 8      Greek Restaurant  Comfort Food Restaurant
#
#            8th Most Common Venue 9th Most Common Venue  \
# 8  Vegetarian / Vegan Restaurant    Seafood Restaurant
#
#       10th Most Common Venue
# 8  Middle Eastern Restaurant

# %% [markdown]
# This is Turkish Restaurant cluster

# %% [markdown]
# cluster 5

# %%
Cologne_merged.loc[Cologne_merged['Cluster Labels'] == 4, Cologne_merged.columns[[1] + list(range(5, Cologne_merged.shape[1]))]]
# Out:
#                                           City parts  \
# 0  Altstadt-Nord, Altstadt-Süd, Deutz, Neustadt-N...
# 3  Bickendorf, Bocklemünd/Mengenich, Ehrenfeld, N...
# 4  Bilderstöckchen, Longerich, Mauenheim, Niehl, ...
# 7  Brück, Höhenberg, Humboldt/Gremberg, Kalk, Mer...
#
#                                    District Councils   Latitude  Longitude  \
# 0  Bezirksksamt Innenstadt Brückenstraße 19, D-50...  50.937328   6.959234
# 3  Bezirksamt Ehrenfeld Venloer Straße 419 – 421,...  50.951502   6.916529
# 4   Bezirksamt NippesNeusser Straße 450,D-50733 Köln  50.958994   6.941777
# 7  Bezirksamt KalkKalker Hauptstraße 247–273,D-51...  50.931923   7.005806
#
#    Cluster Labels 1st Most Common Venue  2nd Most Common Venue  \
# 0               4    Italian Restaurant  Vietnamese Restaurant
# 3               4            Restaurant     Italian Restaurant
# 4               4    Italian Restaurant      German Restaurant
# 7               4            Restaurant     Italian Restaurant
#
#         3rd Most Common Venue  4th Most Common Venue  \
# 0  Modern European Restaurant      German Restaurant
# 3           German Restaurant    Japanese Restaurant
# 4            Greek Restaurant      French Restaurant
# 7            Greek Restaurant  Vietnamese Restaurant
#
#        5th Most Common Venue 6th Most Common Venue    7th Most Common Venue  \
# 0           Sushi Restaurant     French Restaurant       Israeli Restaurant
# 3           Sushi Restaurant    Spanish Restaurant       Falafel Restaurant
# 4           Sushi Restaurant    Spanish Restaurant               Restaurant
# 7  Middle Eastern Restaurant      Asian Restaurant  Comfort Food Restaurant
#
#   8th Most Common Venue          9th Most Common Venue  \
# 0   Japanese Restaurant  Vegetarian / Vegan Restaurant
# 3      Kebab Restaurant              French Restaurant
# 4      Kebab Restaurant     Modern European Restaurant
# 7      Doner Restaurant    Eastern European Restaurant
#
#        10th Most Common Venue
# 0          Falafel Restaurant
# 3  Modern European Restaurant
# 4       Vietnamese Restaurant
# 7           German Restaurant

# %% [markdown]
# This is Italian Restaurant cluster
